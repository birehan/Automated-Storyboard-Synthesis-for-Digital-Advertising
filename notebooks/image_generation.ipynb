# %% [markdown]
# ## Image Generation - Asset Generation
#
# Asset Image generation using 3 models
# -  DLLLE-3 - Open AI
# - Fooocus - Stable Diffusion
# - Automaic1111 - Stable Diffusion

# %% [markdown]
# ### Import packages

# %%
import os
import sys
from IPython.display import Image
import io
import base64

sys.path.append(os.path.abspath(os.path.join('../scripts')))

# %%
from image_generator_fooocus import generate_image_fooocus, download_image_fooocus
from image_generator_dlle3 import generate_image_dlle3, download_image_dlle3
from image_generator_automatic1111 import generate_image_automatic, download_image_automatic

# %% [markdown]
# ### Generate Image Using Fooocus API

# %%
prompt = "Background: A high-resolution 3D Coca-Cola bottle center-screen, bubbles rising to the top, transitioning into a sleek DJ turntable withImageGenerater a vinyl record that has the Coke Studio logo."

# %%
response = generate_image_fooocus(prompt=prompt,aspect_ratios_selection="1024*960")
# Out:
# INFO:httpx:HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# INFO:httpx:HTTP Request: GET https://api.replicate.com/v1/models/konieshadow/fooocus-api-anime/versions/a750658f54c4f8bec1c8b0e352ce2666c22f2f919d391688ff4fc16e48b3a28f "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.replicate.com/v1/predictions/tnlnlwdb6vdeluzishw26ns6yu "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.replicate.com/v1/predictions/tnlnlwdb6vdeluzishw26ns6yu "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.replicate.com/v1/predictions/tnlnlwdb6vdeluzishw26ns6yu "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.replicate.com/v1/predictions/tnlnlwdb6vdeluzishw26ns6yu "HTTP/1.1 200 OK"
# INFO:root:Image generated successfully.

# %%
response
# Out:
# ['https://replicate.delivery/pbxt/R6n8Ua9FEG6rL9VJZjy2wfzS31ZALheqKmLoCSdCNdrGrPXSA/bfb41d27-df8f-43f2-842d-bbc91a2f42a3.png']

# %%
Image(url= response[0])
# Out:
# <img src="https://replicate.delivery/pbxt/azAhBtZAatboHh6qX3VlwIgXJHFttMZXpCWWf9wwvbu5ndLJA/b84396a0-80b7-4ddb-8cf1-664ee3a67e6f.png"/>

# %%
download_image_fooocus(
    url="https://replicate.delivery/pbxt/azAhBtZAatboHh6qX3VlwIgXJHFttMZXpCWWf9wwvbu5ndLJA/b84396a0-80b7-4ddb-8cf1-664ee3a67e6f.png",
    save_path="../generated_assets/storyboard_1/frame_1", 
    image_name="background_image")
# Out:
# INFO:root:Image saved to ../generated_assets/storyboard_1/frame_1/background_image.png
# ('https://replicate.delivery/pbxt/azAhBtZAatboHh6qX3VlwIgXJHFttMZXpCWWf9wwvbu5ndLJA/b84396a0-80b7-4ddb-8cf1-664ee3a67e6f.png',
#  '../generated_assets/storyboard_1/frame_1/background_image.png')

# %% [markdown]
# ### Generate Image Using DLLE-3 OpenAI

# %%
response = generate_image_dlle3(prompt)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# 2024-02-15 17:04:16,767:logger:Image generated successfully
# INFO:logger:Image generated successfully

# %%
response = 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-3fs8YtdSEsz0I4L7lvp9c4pp.png?st=2024-02-15T13%3A04%3A16Z&se=2024-02-15T15%3A04%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-15T02%3A24%3A44Z&ske=2024-02-16T02%3A24%3A44Z&sks=b&skv=2021-08-06&sig=l%2B5qZvYV/FjDt33iZoSURAKbB5HGWCfZnUcN6Xbm52o%3D'

# %%
url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-CqV7n20zPyVdzSR9X4kWKUlg.png?st=2024-02-15T11%3A29%3A16Z&se=2024-02-15T13%3A29%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-15T02%3A27%3A42Z&ske=2024-02-16T02%3A27%3A42Z&sks=b&skv=2021-08-06&sig=Ea7OAFAk%2BiIlwLVgxb%2BD3O6EVL75FOoIUZqyPwd5hDQ%3D'
image = Image(url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-CqV7n20zPyVdzSR9X4kWKUlg.png?st=2024-02-15T11%3A29%3A16Z&se=2024-02-15T13%3A29%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-15T02%3A27%3A42Z&ske=2024-02-16T02%3A27%3A42Z&sks=b&skv=2021-08-06&sig=Ea7OAFAk%2BiIlwLVgxb%2BD3O6EVL75FOoIUZqyPwd5hDQ%3D')

# %%
Image(url= response)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-CqV7n20zPyVdzSR9X4kWKUlg.png?st=2024-02-15T11%3A29%3A16Z&se=2024-02-15T13%3A29%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-15T02%3A27%3A42Z&ske=2024-02-16T02%3A27%3A42Z&sks=b&skv=2021-08-06&sig=Ea7OAFAk%2BiIlwLVgxb%2BD3O6EVL75FOoIUZqyPwd5hDQ%3D"/>

# %%
download_image_dlle3(
    url=response,
    save_path="../generated_assets/storyboard_1/frame_1", 
    image_name="background_image")
# Out:
# 2024-02-15 17:07:05,263:logger:Image saved to ../generated_assets/storyboard_1/frame_1/background_image_2.png
# INFO:logger:Image saved to ../generated_assets/storyboard_1/frame_1/background_image_2.png
# ('https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-3fs8YtdSEsz0I4L7lvp9c4pp.png?st=2024-02-15T13%3A04%3A16Z&se=2024-02-15T15%3A04%3A16Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-15T02%3A24%3A44Z&ske=2024-02-16T02%3A24%3A44Z&sks=b&skv=2021-08-06&sig=l%2B5qZvYV/FjDt33iZoSURAKbB5HGWCfZnUcN6Xbm52o%3D',
#  '../generated_assets/storyboard_1/frame_1/background_image_2.png')

# %% [markdown]
# ### Generate Image Using Automatic1111

# %%
response = generate_image_automatic(prompt, width=320, height=480)

# %%
response
# Out:
# {'images': ['...'],
#  'parameters': {'prompt': 'Background: A high-resolution 3D Coca-Cola bottle center-screen, bubbles rising to the top, transitioning into a sleek DJ turntable withImageGenerater a vinyl record that has the Coke Studio logo.',
#   'negative_prompt': '',
#   'styles': None,
#   'seed': -1,
#   'subseed': -1,
#   'subseed_strength': 0,
#   'seed_resize_from_h': -1,
#   'seed_resize_from_w': -1,
#   'sampler_name': None,
#   'batch_size': 1,
#   'n_iter': 1,
#   'steps': 5,
#   'cfg_scale': 7.0,
#   'width': 320,
#   'height': 480,
#   'restore_faces': None,
#   'tiling': None,
#   'do_not_save_samples': False,
#   'do_not_save_grid': False,
#   'eta': None,
#   'denoising_strength': None,
#   's_min_uncond': None,
#   's_churn': None,
#   's_tmax': None,
#   's_tmin': None,
#   's_noise': None,
#   'override_settings': None,
#   'override_settings_restore_afterwards': True,
#   'refiner_checkpoint': None,
#   'refiner_switch_at': None,
# ...

# %%
from PIL import Image

Image.open(io.BytesIO(base64.b64decode(response['images'][0])))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x480>

# %%
download_image_automatic(
    url=response['images'][0],
    save_path="../generated_assets/storyboard_1/frame_1", 
    image_name="background_image")
# Out:
# 2024-02-16 14:46:00,972:logger:Image saved to ../generated_assets/storyboard_1/frame_1/background_image_4.png
# INFO:logger:Image saved to ../generated_assets/storyboard_1/frame_1/background_image_4.png
# ('...',
#  '../generated_assets/storyboard_1/frame_1/background_image_4.png')
